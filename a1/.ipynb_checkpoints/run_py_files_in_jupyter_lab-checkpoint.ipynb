# %% [markdown]
# # Run Python Files (.py) in JupyterLab
# Demonstrating script execution, imports, and magics.

# %%
# 1. Run test.py using %run
# %run test.py
# %run -t -N3 test.py
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
#
# IPython CPU timings (estimated):
# Total runs performed: 3
#   Times  :      Total      Per run
#   User   :       0.00 s,       0.00 s.
#   System :       0.00 s,       0.00 s.
# Wall time:       0.00 s.

# %%
# 2. Import
import test

# %%
# %%writefile demo.py
print("Hello from demo file!")
# Out:
# Writing demo.py
