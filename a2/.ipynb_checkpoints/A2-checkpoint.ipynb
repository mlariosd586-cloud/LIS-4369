# %%
# %run my_env_versions.py
# Out:
# Python version:
# 3.14.7 | packaged by Anaconda, Inc. | (main, Aug 14 2026, 10:13:42) [Clang 20.1.8 ]
# jupyterlab: 4.6.3
# pandas: 3.0.5
# pandas_datareader: 0.11.1
# numpy: 2.5.2
# matplotlib: 3.11.2
# sklearn: 1.9.1
# django: 6.1.1
# seaborn: 0.13.2
# openpyxl: 3.1.5
# nltk: 3.10.3
# statsmodels: 0.15.0
# scipy: 1.18.1
# cv2 (opencv-python): 5.0.0
# yfinance: 1.7.0

# %%
import pandas as pd
df_patients = pd.read_csv("data/patients.csv")
df_patients
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
type(df_patients)
# Out:
# pandas.DataFrame

# %%
df_patients.shape
# Out:
# (1000000, 13)

# %%
df_patients.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Visit_Date     1000000 non-null  str
#  1   Patient_ID     1000000 non-null  int64
#  2   Age            1000000 non-null  int64
#  3   Gender         1000000 non-null  str
#  4   Diagnosis      1000000 non-null  str
#  5   Has_Insurance  1000000 non-null  bool
#  6   Postcode       1000000 non-null  int64
#  7   Total_Cost     1000000 non-null  float64
#  8   Registration   1000000 non-null  int64
#  9   Nursing        1000000 non-null  int64
#  10  Laboratory     1000000 non-null  int64
#  11  Consultation   1000000 non-null  int64
#  12  Pharmacy       1000000 non-null  int64
# dtypes: bool(1), float64(1), int64(8), str(3)
# memory usage: 92.5 MB

# %%
df_patients.isna()

df_patients.isna().sum()


df_patients = df_patients.dropna()
df_patients
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
df_patients.head()

df_patients.tail()

df_patients.head(10)
# Out:
#    Visit_Date  Patient_ID  Age  Gender                          Diagnosis  \
# 0  2020-05-06      688923   68  Female                           Diabetes
# 1  2018-08-04      886361   62  Female            Urinary Tract Infection
# 2  2021-04-10      464823   70  Female  Upper Respiratory Tract Infection
# 3  2021-10-01      655214    8  Female  Upper Respiratory Tract Infection
# 4  2018-04-30      454666   24    Male                            Malaria
# 5  2022-06-22       47297   14    Male                      Ear Infection
# 6  2022-03-30      703464   52    Male            Urinary Tract Infection
# 7  2021-12-19      969327   44  Female                            Malaria
# 8  2020-09-16      246521   55    Male                           Diabetes
# 9  2022-04-23      796347   68  Female                           Diabetes
#
#    Has_Insurance  Postcode  Total_Cost  Registration  Nursing  Laboratory  \
# 0           True     20006      2274.0            33      105         101
# ...

# %%
df_patients.rename(columns={'Registration': 'Registration_mins'})

df_patients.head()

df_patients.rename(columns={'Registration': 'Registration_mins'}, inplace=True)
df_patients.head()

column_mapping = {
    'Postcode': 'Zip',
    'Nursing': 'Nursing_mins',
    'Laboratory': 'Laboratory_mins',
    'Consultation': 'Consultation_mins',
    'Pharmacy': 'Pharmacy_mins'}

df_patients.rename(columns=column_mapping, inplace=True)
df_patients.head()
# Out:
#    Visit_Date  Patient_ID  Age  Gender                          Diagnosis  \
# 0  2020-05-06      688923   68  Female                           Diabetes
# 1  2018-08-04      886361   62  Female            Urinary Tract Infection
# 2  2021-04-10      464823   70  Female  Upper Respiratory Tract Infection
# 3  2021-10-01      655214    8  Female  Upper Respiratory Tract Infection
# 4  2018-04-30      454666   24    Male                            Malaria
#
#    Has_Insurance    Zip  Total_Cost  Registration_mins  Nursing_mins  \
# 0           True  20006      2274.0                 33           105
# 1          False  20005      3430.0                 46            75
# 2           True  10003      1836.0                107            81
# 3          False  10006      3250.0                 66            31
# 4           True  10006      2262.0                 68            55
#
#    Laboratory_mins  Consultation_mins  Pharmacy_mins
# ...

# %%
df_patients.to_csv('data/patients_clean.csv')

pd.read_csv("data/patients_clean.csv")

df_patients.to_csv('data/patients_clean.csv', index=False)

df_patients = pd.read_csv("data/patients_clean.csv")
df_patients
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance    Zip  Total_Cost  \
# 0                                Diabetes           True  20006      2274.0
# 1                 Urinary Tract Infection          False  20005      3430.0
# 2       Upper Respiratory Tract Infection           True  10003      1836.0
# 3       Upper Respiratory Tract Infection          False  10006      3250.0
# ...

# %%
patient_insurance = df_patients['Has_Insurance'].value_counts()

import matplotlib.pyplot as plt

patient_insurance.plot(kind='bar')
plt.show()
